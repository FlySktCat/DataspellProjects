# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from TP07_K_plus_proches_voisins.src.utils import add_decision_boundary
import warnings
warnings.filterwarnings("ignore")

# %%
#Q1
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

Xy = pd.read_csv("TP11_Arbres_de_decision/data/toy2.csv")
X = Xy. iloc[:, :-1]
y = Xy. iloc[:, -1]
cls = DecisionTreeClassifier (max_depth=4)
cls. fit (X, y)
plt.figure (figsize=(10, 8))
plot_tree(cls, fontsize=12)
plt.show()

# %%
print(cls.tree_.impurity.shape)
cls.tree_.impurity[0]
# Out:
# (13,)
# 0.4970414201183432

# %%
cls.tree_.children_right[0]
# Out:
# 8

# %%
Xy.columns=["X0", "X1" ,"y"]
sns. scatterplot (x="X0", y="X1", hue="y", data=Xy)
add_decision_boundary(cls)
plt.savefig ('toy_data.pdf', dpi=600)

# %%
#Q3
gini_left = cls. tree_. impurity [cls.tree_.children_left [0]]
print ('Gini_left =', gini_left)
gini_right = cls.tree_. impurity[cls. tree_.children_right [0]]
print ('Gini_right =', gini_right)
count_left = cls.tree_.n_node_samples[cls.tree_.children_left[0]]
print (' Count_left =', count_left)
count_right = cls.tree_.n_node_samples[cls.tree_.children_right[0]]
print('Count_right =', count_right)
gain = (count_left * gini_left + count_right * gini_right) / (count_left + count_right)
print ('Gain =', gain)
# Out:
# Gini_left = 0.40816326530612246
# Gini_right = 0.2777777777777778
#  Count_left = 7
# Count_right = 6
# Gain = 0.34798534798534797

# %%
#Q4
Xy = pd.read_csv("TP07_K_plus_proches_voisins/data/Synth1-2000.csv")
X = Xy.iloc[:,:-1]
y = Xy.iloc[:,-1]
from sklearn.utils import resample
X1,y1 = resample(X, y)
X2,y2 = resample(X, y)
X3,y3 = resample(X, y)

# %%
#Q5
from sklearn. tree import DecisionTreeClassifier
params ={"max_leaf_nodes": 30}
clf1 = DecisionTreeClassifier (**params)
clf1.fit (X1, y1)
sns. scatterplot (x="X1", y= "X2", hue='y', data=Xy)
add_decision_boundary (clf1)
plt.show()

# %%
#Q6
def aggregating (X):
    y1 = clf1. predict (X)
    y2 = clf2. predict (X)
    y3 = clf3. predict (X)
    return np.where ((y1 + y2 + y3) > 1.5, 1, 0)

sns. scatterplot (x="X1", y="X2", hue="y", data=Xy)
add_decision_boundary (aggregating, model_classes=[0, 1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/m8/s_9pq18x4l3608_drs52xs3c0000gn/T/ipykernel_84735/2741254751.py in <module>
#       7
#       8 sns. scatterplot (x="X1", y="X2", hue="y", data=Xy)
# ----> 9 add_decision_boundary (aggregating, model_classes=[0, 1])
#      10 plt.show()
#
# ~/DataspellProjects/dsProject/TP07_K_plus_proches_voisins/src/utils.py in add_decision_boundary(model, resolution, ax, levels, label, color, region, model_classes)
#     134
#     135         # Model is a predict function, no levels
# --> 136         Z_num, num2cat = get_regions(model, xy, XX.shape, model_classes)
#     137         draw_boundaries(XX, YY, Z_num, color)
#     138         if region:
#
# ~/DataspellProjects/dsProject/TP07_K_plus_proches_voisins/src/utils.py in get_regions(predict_fun, xy, shape, model_classes)
#      62
#      63     def get_regions(predict_fun, xy, shape, model_classes):
# ---> 64         Z_pred = predict_fun(xy).reshape(shape)
#      65         cat2num = {cat: num for num, cat in enumerate(model_classes)}
#      66         num2cat = {num: cat for num, cat in enumerate(model_classes)}
#
# /var/folders/m8/s_9pq18x4l3608_drs52xs3c0000gn/T/ipykernel_84735/2741254751.py in aggregating(X)
#       2 def aggregating (X):
#       3     y1 = clf1. predict (X)
# ----> 4     y2 = clf2. predict (X)
#       5     y3 = clf3. predict (X)
#       6     return np.where ((y1 + y2 + y3) > 1.5, 1, 0)
#
# NameError: name 'clf2' is not defined

# %%
clf3 = DecisionTreeClassifier(**params)
clf3.fit(X3,y3)
sns

# %%
#Q9
