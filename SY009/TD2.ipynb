# %% [markdown]
# TP02

# %%
import seaborn as sns
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic") #从网上下载数据
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=titanic["age"]) #箱图
plt.show()

# %%
sns.scatterplot(x="sepal_length", y = "sepal_width", data=iris)#点图
plt.show()

# %%
#Q12
sns.displot(x="age",col="class", kind="hist", data=titanic)
plt.show()

# %% [markdown]
# # TP03

# %%
import pandas as pd
import numpy as np
import numpy.linalg as linalg
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def add_labels(x_list, y_list, labels):
    for x, y, label in zip(x_list, y_list, labels):
        plt.text(x+0.25, y-0.25, label)

# %% [markdown]
# # Q1

# %%
notes =pd.read_csv("TP03_Representation_euclidienne_des_donnees-enonce/data/notes.txt",sep="\s+")
plt.scatter(notes.math, notes.scie)
add_labels(notes.math, notes.scie, notes.index)
plt.show()

# %% [markdown]
# # Q2.1

# %%
notes0 = notes.reset_index()
notes_melt = notes0.melt(id_vars=["index"], var_name="Matiere", value_name="Note")
sns.barplot(x="index", y="Note", hue="Matiere", data=notes_melt)
plt.show()

# %% [markdown]
# # Q2.2

# %%
corr = notes.corr()
sns.heatmap(corr)
plt.show()

# %% [markdown]
# # Q3.1

# %%
plt.scatter(notes.math, notes.scie)
plt.xlabel('math')
plt.ylabel('scei')
add_labels(notes.math, notes.scie, notes.index)
plt.show()

# %% [markdown]
# # Q4

# %%
plt.scatter((notes.math + notes.scie) / 2,( notes.fran + notes.lati) / 2)
plt.xlabel('mean math-scie')
plt.ylabel('mean fran-lati')
plt.plot([5,15], [10,10])
plt.plot([10,10], [5,15])
add_labels((notes.math + notes.scie) / 2, (notes.fran + notes.lati) / 2, notes.index)
plt.show()

# %% [markdown]
# # Q5 <aj..ak..>=0 任意 j！=k

# %% [markdown]
# # Q8

# %%
Xc= notes[['math', 'scie', 'fran', 'lati', 'd-m']].to_numpy()
C= np.cov(Xc, bias=True, rowvar=False)
np.diag(C).sum()
# Out:
# 48.97530864197531

# %% [markdown]
# # Q9

# %%
A1 = np.array([[0.5, 0, 0.5, 0, 0],
              [0.5, 0, -0.5, 0, 0],
              [0, 0.5, 0, 0.5, 0],
              [0, 0.5, 0, -0.5, 0],
              [0, 0, 0, 0, 1],]
              )
C1 = np.cov(Xc @ linalg.inv(A1).T, bias=True, rowvar=False)
np.diag(C1).sum()
# Out:
# 89.28395061728395
